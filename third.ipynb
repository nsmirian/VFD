# %%
import time
#import pydoocs
import numpy as np
import matplotlib.pyplot as plt
import h5py
import pandas as pd
#import cv2
import seaborn as sns
import struct
import pprint

# %%
f=h5py.File('PBD2_VRFD_pbd2_stream_6_run52040_file116_20240227T153325.hdf5', 'r+')
f.keys()
# Out:
# <KeysViewHDF5 ['FLASH.DIAG', 'FLASH.FEL', 'FLASH.MAGNETS', 'FLASH.RF', 'FLASH.SDIAG']>

# %%
f.close()
import tables
tables.file._open_files.close_all()

# %%
print(f['FLASH.FEL'].keys())
print(f['FLASH.FEL/XGM.INTENSITY'].keys())
print(f['FLASH.FEL/XGM.INTENSITY/FL2.TUNNEL'].keys())
f['FLASH.FEL/XGM.INTENSITY/FL2.TUNNEL/INTENSITY.TD'][180,1]
print(f['FLASH.FEL/XGM.INTENSITY/FL2.TUNNEL/INTENSITY.TD'].shape)
# Out:
# <KeysViewHDF5 ['XGM.INTENSITY']>
# <KeysViewHDF5 ['FL2.TUNNEL']>
# <KeysViewHDF5 ['INTENSITY.SIGMA.TD', 'INTENSITY.TD', 'INTENSITY_AUX.TD', 'TSS', 'TimeStamp', 'TrainId', 'X.SIGMA.TD', 'X.TD', 'Y.SIGMA.TD', 'Y.TD']>
# (710, 3)

# %%
plt.plot(f['FLASH.FEL/XGM.INTENSITY/FL2.TUNNEL/INTENSITY.TD'][:,:], 'o')

# %%
del f['FLASH.FEL']

# %%
f.keys()
# Out:
# <KeysViewHDF5 ['FLASH.DIAG', 'FLASH.MAGNETS', 'FLASH.RF', 'FLASH.SDIAG']>

# %%
f.close()
import tables
tables.file._open_files.close_all()

# %%
f=h5py.File('PBD2_VRFD_pbd2_stream_6_run52040_file112_20240227T152019.hdf5', 'r')

# %%
plt.plot(f['FLASH.FEL/XGM.INTENSITY/FL2.TUNNEL/INTENSITY.TD'][:,0], 'o')

# %%
f=h5py.File('PBD2_VRFD_pbd2_stream_6_run52040_file114_20240227T153103.hdf5', 'r')
plt.plot(f['FLASH.FEL/XGM.INTENSITY/FL2.TUNNEL/INTENSITY.TD'][:,0], 'o')

# %%
f=h5py.File('PBD2_VRFD_pbd2_stream_6_run52040_file115_20240227T153214.hdf5', 'r')
plt.plot(f['FLASH.FEL/XGM.INTENSITY/FL2.TUNNEL/INTENSITY.TD'][:,0], 'o')
